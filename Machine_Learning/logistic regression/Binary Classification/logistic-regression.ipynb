# %% [markdown]
# # Classification

# %% [markdown]
# Categorical data.
#
# Target - classes/categories
#
# Regression
# Homeprices - target was in continuous format
#
# Classification
# Predicting if an email is spam or not?
# Target - spam / not spam
#
# Types of classication
# a. Binary Classification - 2 classes.
# Example: Detecting if an email is spam or not
# Example: Detecting a heart failure or not?
#
# b. Multi-classification - more than 2 classes
# Example: Predicting if a team will win, draw or lose
#
#
# Algorithms/functions/models under classification
# 1. Logistic Regression
# 2. ...

# %% [markdown]
# ## Binary Classification

# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score,confusion_matrix,ConfusionMatrixDisplay

# %%
df = pd.read_csv("insurance_data.csv")
df
# Out:
#     age  bought_insurance
# 0    22                 0
# 1    25                 0
# 2    47                 1
# 3    52                 0
# 4    46                 1
# 5    56                 1
# 6    55                 0
# 7    60                 1
# 8    62                 1
# 9    61                 1
# 10   18                 0
# 11   28                 0
# 12   27                 0
# 13   29                 0
# 14   49                 1
# 15   55                 1
# 16   25                 1
# 17   58                 1
# 18   19                 0
# 19   18                 0
# 20   21                 0
# 21   26                 0
# 22   40                 1
# 23   45                 1
# 24   50                 1
# 25   54                 1
# 26   23                 0

# %%
# features/predictors
X = df['age'] # this is used to predict the target variable
y = df['bought_insurance']

# %%
y=pd.DataFrame(y,columns=['bought_insurance'])
y
# Out:
#     bought_insurance
# 0                  0
# 1                  0
# 2                  1
# 3                  0
# 4                  1
# 5                  1
# 6                  0
# 7                  1
# 8                  1
# 9                  1
# 10                 0
# 11                 0
# 12                 0
# 13                 0
# 14                 1
# 15                 1
# 16                 1
# 17                 1
# 18                 0
# 19                 0
# 20                 0
# 21                 0
# 22                 1
# 23                 1
# 24                 1
# 25                 1
# 26                 0

# %%
X = pd.DataFrame(X,columns=['age'])
X
# Out:
#     age
# 0    22
# 1    25
# 2    47
# 3    52
# 4    46
# 5    56
# 6    55
# 7    60
# 8    62
# 9    61
# 10   18
# 11   28
# 12   27
# 13   29
# 14   49
# 15   55
# 16   25
# 17   58
# 18   19
# 19   18
# 20   21
# 21   26
# 22   40
# 23   45
# 24   50
# 25   54
# 26   23

# %%
X_train,X_test,y_train,y_test = train_test_split(X,y,train_size=0.8)

# %%
# define our model
logReg = LogisticRegression()

# %%
# Train our model
logReg.fit(X_train,y_train)
# Out:
# /home/njoroge/.local/lib/python3.10/site-packages/sklearn/utils/validation.py:1300: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# LogisticRegression()

# %%
# Predictions
y_pred = logReg.predict(X_test)

# %%
logReg.score(X_test,y_test)
# Out:
# 0.8333333333333334

# %%
accuracy_score(y_pred,y_test)
# Out:
# 0.8333333333333334

# %% [markdown]
# ## Confusion Matrix

# %% [markdown]
# True true
# True false
# False true
# False false

# %%
cm = confusion_matrix(y_test,y_pred)

# %%
cm
# Out:
# array([[3, 0],
#        [1, 2]])

# %%
cm_disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=[False,True] )

# %%
cm_disp.plot()
